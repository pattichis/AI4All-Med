# %% [markdown]
# <a href="https://colab.research.google.com/github/pattichis/AIML/blob/main/Session_3_2_Escape_the_Maze_Game.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Goals

# %% [markdown]
# 1. A fun activity with while, if, and a robot.
# 2. Demonstrate a simple example of autonomous AI.

# %% [markdown]
# # Installations

# %%
# !pip install pygame
# !pip install opencv-python
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.0/14.0 MB 111.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.0/63.0 MB 19.0 MB/s eta 0:00:00
# ...

# %%
# !wget https://raw.githubusercontent.com/ivpcl/AOLME_Level2/main/RobotMazeSimulation/RobotMazeSimulationGoogleColab/robot.png
# !wget https://raw.githubusercontent.com/ivpcl/AOLME_Level2/main/RobotMazeSimulation/RobotMazeSimulationGoogleColab/RobotMazeSetting.py
# !wget https://raw.githubusercontent.com/ivpcl/AOLME_Level2/main/RobotMazeSimulation/RobotMazeSimulationGoogleColab/AOLME.py
# Out:
# --2025-06-04 11:51:51--  https://raw.githubusercontent.com/ivpcl/AOLME_Level2/main/RobotMazeSimulation/RobotMazeSimulationGoogleColab/robot.png
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.111.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3505 (3.4K) [image/png]
# Saving to: ‘robot.png’
#
# robot.png           100%[===================>]   3.42K  --.-KB/s    in 0s
#
# 2025-06-04 11:51:52 (88.1 MB/s) - ‘robot.png’ saved [3505/3505]
#
# --2025-06-04 11:51:52--  https://raw.githubusercontent.com/ivpcl/AOLME_Level2/main/RobotMazeSimulation/RobotMazeSimulationGoogleColab/RobotMazeSetting.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# ...

# %%
import os
os.environ["SDL_VIDEODRIVER"] = "dummy"
from IPython.display import HTML
import AOLME
from RobotMazeSetting import RobotMazeSetting
# Out:
# pygame 2.6.1 (SDL 2.28.4, Python 3.11.12)
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %% [markdown]
# # Program the game

# %% [markdown]
# 1. Study the code below.
# 2. Modify the movements.
# 3. Can you modify the code to escape the Maze?

# %%
#  Movement commands:
#  Move forward:  gopi.fw(second)
#  Move backward: gopi.bw(second)
#  Move left:     gopi.lt(second)
#  Move right:    gopi.rt(second)
#  Turn right:    gopi.rtd(num_of_degrees)
#  Turn left:     gopi.ltd(num_of_degrees)


# Store the video frames.
frame_list = []

# Speed of the robot:
robot_speed =  3

# Initialize:
gopi       =  RobotMazeSetting(robot_speed, frame_list)
collision  =  False
final       =  False
time       =  True


# Modify this loop
while(final==False and time == True):
  if collision == False:
    collision, final, time = gopi.fw(10) # Modify
  else:
    collision, final, time = gopi.bw(4)  # Modify
    collision, final = gopi.ltd(50)      # Modify

#gopi.run_game()

all_frames = gopi.frame_list
print(len(all_frames))

fps = 60
play_video = AOLME.vid_show(all_frames, fps)
print('Video is ready')
# Out:
# Move forward 10s
# Move forward 10s
# Move forward 10s
# Move forward 10s
# Cannot move
# Cannot move forward
# Move backward 4s
# Turn left 50 degrees
# Move forward 10s
# Cannot move
# Cannot move forward
# Move backward 4s
# Turn left 50 degrees
# Move forward 10s
# Cannot move
# Cannot move forward
# Move backward 4s
# Turn left 50 degrees
# Move forward 10s
# Cannot move
# Cannot move forward
# Move backward 4s
# Turn left 50 degrees
# Move forward 10s
# Move forward 10s
# Cannot move
# Cannot move forward
# Move backward 4s
# Turn left 50 degrees
# Move forward 10s
# Move forward 10s
# Cannot move
# Cannot move forward
# Move backward 4s
# Turn left 50 degrees
# Move forward 10s
# Move forward 10s
# Move forward 10s
# Move forward 10s
# Move forward 10s
# Move forward 10s
# Move forward 10s
# Move forward 10s
# Cannot move
# Cannot move forward
# Move backward 4s
# Turn left 50 degrees
# Move forward 10s
# Move forward 10s
# Cannot move
# Cannot move forward
# Move backward 4s
# ...

# %%
final_video = play_video.to_html5_video()

# %%
HTML("""
<video controls>
      <source src="%s" >
</video>
""" % final_video)
# Out:
# <video controls>
#       <source src="<video width="1500" height="1000" controls autoplay loop>
#   <source type="video/mp4" src="...
